# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import boxcox
from scipy.special import inv_boxcox
pd.set_option('display.float_format', '{:.3f}'.format)

# %% [markdown]
# ## Helper function to generate report

# %%
def getQoF(mod, cname, key, lam=0.2):
    
    y_true = mod.model.data.frame[cname].values
    y_pred = mod.fittedvalues
    
    if key == "orig":
        pass
    elif key == "sqrt":
        y_pred = y_pred**2
    elif key == "log1p":
        y_pred = np.expm1(y_pred)
    elif key == "boxcox":
        y_pred = inv_boxcox(y_pred, lam)

    mae = np.mean(np.abs(y_true - y_pred))
    
    smape = 100 * np.mean(
        2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred))
    )

    metrics = {
        "rSq": mod.rsquared,
        "rSqBar": mod.rsquared_adj,
        "sst": mod.centered_tss,
        "sse": mod.ssr,
        "sde": np.sqrt(mod.mse_resid),
        "mse0": mod.mse_resid,
        "rmse": np.sqrt(mod.mse_resid),
        "mae": mae,
        "smape": smape,
        "m": mod.nobs,
        "dfr": mod.df_model,
        "df": mod.df_resid,
        "fStat": mod.fvalue,
        "aic": mod.aic,
        "bic": mod.bic
    }
    return metrics

# %% [markdown]
# # Auto MPG: Square-Root, Log1p, and Box–Cox Transformations

# %% [markdown]
# ### Data Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import boxcox
from scipy.special import inv_boxcox

auto_mpg = pd.read_csv("dt/auto-mpg.csv",na_values="?", on_bad_lines="skip").dropna()
auto_mpg.rename(columns={"model year": "model_year"}, inplace=True)
auto_mpg.drop(columns=['car name'], inplace=True)
auto_mpg["mpg"] = auto_mpg.pop("mpg")

auto_mpg['mpg_sqrt']  = np.sqrt(auto_mpg['mpg'])
auto_mpg['mpg_log1p'] = np.log1p(auto_mpg['mpg'])
auto_mpg['mpg_boxcox'] = boxcox(auto_mpg['mpg'], 0.20)

auto_mpg = sm.add_constant(auto_mpg)

auto_mpg.head()
# Out:
#    const  cylinders  displacement  horsepower  weight  acceleration  \
# 0  1.000          8       307.000     130.000    3504        12.000
# 1  1.000          8       350.000     165.000    3693        11.500
# 2  1.000          8       318.000     150.000    3436        11.000
# 3  1.000          8       304.000     150.000    3433        12.000
# 4  1.000          8       302.000     140.000    3449        10.500
#
#    model_year  origin    mpg  mpg_sqrt  mpg_log1p  mpg_boxcox
# 0          70       1 18.000     4.243      2.944       3.913
# 1          70       1 15.000     3.873      2.773       3.594
# 2          70       1 18.000     4.243      2.944       3.913
# 3          70       1 16.000     4.000      2.833       3.706
# 4          70       1 17.000     4.123      2.890       3.812

# %% [markdown]
# ### Auto MPG Regression: Square-Root Transformation

# %%
model_sqrt = smf.ols(formula = 'mpg_sqrt ~ const + cylinders + displacement + horsepower + weight + acceleration + model_year', data=auto_mpg).fit()
print(model_sqrt.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mpg_sqrt   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     357.1
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):          6.43e-154
# Time:                        00:30:30   Log-Likelihood:                -100.91
# No. Observations:                 392   AIC:                             215.8
# Df Residuals:                     385   BIC:                             243.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6521      0.219      2.978      0.003       0.222       1.083
# const            0.6521      0.219      2.978      0.003       0.222       1.083
# cylinders       -0.0455      0.031     -1.489      0.137      -0.106       0.015
# displacement     0.0007      0.001      1.050      0.295      -0.001       0.002
# horsepower      -0.0011      0.001     -0.864      0.388      -0.004       0.001
# weight          -0.0007   6.16e-05    -10.779      0.000      -0.001      -0.001
# acceleration     0.0031      0.009      0.335      0.738      -0.015       0.022
# model_year       0.0740      0.005     15.303      0.000       0.065       0.084
# ==============================================================================
# Omnibus:                       12.070   Durbin-Watson:                   1.275
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.890
# Skew:                           0.278   Prob(JB):                     0.000354
# Kurtosis:                       3.815   Cond. No.                     8.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.9e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Auto MPG Regression: Log1p Transformation

# %%
model_log1p = smf.ols(formula = 'mpg_log1p ~ const + cylinders + displacement + horsepower + weight + acceleration + model_year', data=auto_mpg).fit()
print(model_log1p.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              mpg_log1p   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     439.2
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):          8.87e-169
# Time:                        00:30:30   Log-Likelihood:                 289.19
# No. Observations:                 392   AIC:                            -564.4
# Df Residuals:                     385   BIC:                            -536.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.9573      0.081     11.825      0.000       0.798       1.116
# const            0.9573      0.081     11.825      0.000       0.798       1.116
# cylinders       -0.0220      0.011     -1.946      0.052      -0.044       0.000
# displacement     0.0003      0.000      1.087      0.278      -0.000       0.001
# horsepower      -0.0009      0.000     -1.909      0.057      -0.002    2.67e-05
# weight          -0.0003   2.28e-05    -11.139      0.000      -0.000      -0.000
# acceleration    -0.0009      0.003     -0.262      0.793      -0.008       0.006
# model_year       0.0284      0.002     15.903      0.000       0.025       0.032
# ==============================================================================
# Omnibus:                        5.064   Durbin-Watson:                   1.335
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                6.811
# Skew:                          -0.019   Prob(JB):                       0.0332
# Kurtosis:                       3.645   Cond. No.                     8.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.9e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Auto MPG Regression: Box-Cox Transformation

# %%
model_boxcox = smf.ols(formula = 'mpg_boxcox ~ const + cylinders + displacement + horsepower + weight + acceleration + model_year', data=auto_mpg).fit()
print(model_boxcox.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             mpg_boxcox   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     411.9
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):          4.01e-164
# Time:                        00:30:30   Log-Likelihood:                 17.852
# No. Observations:                 392   AIC:                            -21.70
# Df Residuals:                     385   BIC:                             6.096
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.9032      0.162      5.583      0.000       0.585       1.221
# const            0.9032      0.162      5.583      0.000       0.585       1.221
# cylinders       -0.0404      0.023     -1.791      0.074      -0.085       0.004
# displacement     0.0005      0.000      1.076      0.283      -0.000       0.002
# horsepower      -0.0014      0.001     -1.533      0.126      -0.003       0.000
# weight          -0.0005   4.55e-05    -11.054      0.000      -0.001      -0.000
# acceleration    -0.0003      0.007     -0.047      0.963      -0.014       0.013
# model_year       0.0563      0.004     15.751      0.000       0.049       0.063
# ==============================================================================
# Omnibus:                        5.625   Durbin-Watson:                   1.313
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                7.494
# Skew:                           0.080   Prob(JB):                       0.0236
# Kurtosis:                       3.658   Cond. No.                     8.01e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.9e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Report

# %%
results = pd.DataFrame({
    "Sqrt":   getQoF(model_sqrt,  "mpg", "sqrt"),
    "Log1p":  getQoF(model_log1p, "mpg", "log1p"),
    "BoxCox": getQoF(model_boxcox,"mpg", "boxcox", lam=0.2)
})

print(results)
# Out:
#           Sqrt    Log1p  BoxCox
# rSq      0.848    0.873   0.865
# rSqBar   0.845    0.871   0.863
# sst    252.161   41.173 155.463
# sse     38.407    5.248  20.953
# sde      0.316    0.117   0.233
# mse0     0.100    0.014   0.054
# rmse     0.316    0.117   0.233
# mae      2.347    2.184   2.233
# smape   10.205    9.320   9.562
# m      392.000  392.000 392.000
# dfr      6.000    6.000   6.000
# df     385.000  385.000 385.000
# fStat  357.118  439.218 411.913
# aic    215.825 -564.387 -21.703
# bic    243.623 -536.589   6.096

# %% [markdown]
# # Boston House Price: Square-Root, Log1p, and Box–Cox Transformations

# %% [markdown]
# ### Data Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import boxcox
from scipy.special import inv_boxcox

house_price = pd.read_csv("boston_house_prices.csv").dropna()
house_price['House_Price_Sqrt'] = np.sqrt(house_price['House_Price'])
house_price['House_Price_Log1p'] = np.log1p(house_price['House_Price'])
house_price['House_Price_Boxcox'] = boxcox(house_price['House_Price'], 0.85)
house_price = sm.add_constant(house_price)

house_price.head()
# Out:
#    const  Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0  1.000            1360             2              1        1981     0.600
# 1  1.000            4272             3              3        2016     4.753
# 2  1.000            3592             1              2        2016     3.635
# 3  1.000             966             1              2        1977     2.731
# 4  1.000            4926             2              1        1993     4.699
#
#    Garage_Size  Neighborhood_Quality  House_Price  House_Price_Sqrt  \
# 0            0                     5   262382.852           512.233
# 1            1                     6   985260.854           992.603
# 2            0                     9   777977.390           882.030
# 3            1                     8   229698.919           479.269
# 4            0                     8  1041740.859          1020.657
#
#    House_Price_Log1p  House_Price_Boxcox
# 0             12.478           47496.920
# 1             13.801          146250.084
# 2             13.564          119646.151
# 3             12.345           42418.386
# 4             13.856          153346.365

# %% [markdown]
# ### Boston House Price Regression: Square-Root Transformation

# %%
model_sqrt = smf.ols(formula = 'House_Price_Sqrt ~ const + Square_Footage + Num_Bedrooms + \
                                Num_Bathrooms + Year_Built + Lot_Size + Garage_Size + \
                                Neighborhood_Quality', data=house_price).fit()
print(model_sqrt.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       House_Price_Sqrt   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     9663.
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                -4445.7
# No. Observations:                1000   AIC:                             8907.
# Df Residuals:                     992   BIC:                             8947.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             -543.3017     31.767    -17.103      0.000    -605.639    -480.964
# const                 -543.3017     31.767    -17.103      0.000    -605.639    -480.964
# Square_Footage           0.1343      0.001    255.730      0.000       0.133       0.135
# Num_Bedrooms             7.0397      0.463     15.196      0.000       6.131       7.949
# Num_Bathrooms            5.5652      0.801      6.952      0.000       3.994       7.136
# Year_Built               0.7106      0.032     22.314      0.000       0.648       0.773
# Lot_Size                10.0132      0.509     19.690      0.000       9.015      11.011
# Garage_Size              3.1392      0.810      3.874      0.000       1.549       4.729
# Neighborhood_Quality     0.2554      0.227      1.123      0.262      -0.191       0.702
# ==============================================================================
# Omnibus:                      151.241   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              228.894
# Skew:                          -1.039   Prob(JB):                     1.98e-50
# Kurtosis:                       4.085   Cond. No.                     1.20e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  9e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Boston House Price Regression: Log1p Transformation

# %%
model_log1p = smf.ols(formula = 'House_Price_Log1p ~ const + Square_Footage + Num_Bedrooms + \
                                Num_Bathrooms + Year_Built + Lot_Size + Garage_Size + \
                                Neighborhood_Quality', data=house_price).fit()
print(model_log1p.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      House_Price_Log1p   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     2280.
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                 710.22
# No. Observations:                1000   AIC:                            -1404.
# Df Residuals:                     992   BIC:                            -1365.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.8168      0.183     20.840      0.000       3.457       4.176
# const                    3.8168      0.183     20.840      0.000       3.457       4.176
# Square_Footage           0.0004   3.03e-06    124.117      0.000       0.000       0.000
# Num_Bedrooms             0.0207      0.003      7.762      0.000       0.015       0.026
# Num_Bathrooms            0.0161      0.005      3.494      0.000       0.007       0.025
# Year_Built               0.0022      0.000     11.923      0.000       0.002       0.003
# Lot_Size                 0.0287      0.003      9.804      0.000       0.023       0.034
# Garage_Size              0.0085      0.005      1.816      0.070      -0.001       0.018
# Neighborhood_Quality     0.0014      0.001      1.060      0.289      -0.001       0.004
# ==============================================================================
# Omnibus:                      281.763   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              734.458
# Skew:                          -1.462   Prob(JB):                    3.27e-160
# Kurtosis:                       6.013   Cond. No.                     1.20e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  9e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Boston House Price Regression: Box-Cox Transformation

# %%
model_boxcox = smf.ols(formula = 'House_Price_Boxcox ~ const + Square_Footage + Num_Bedrooms + \
                                Num_Bathrooms + Year_Built + Lot_Size + Garage_Size + \
                                Neighborhood_Quality', data=house_price).fit()
print(model_boxcox.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     House_Price_Boxcox   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 5.648e+04
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                -8879.9
# No. Observations:                1000   AIC:                         1.778e+04
# Df Residuals:                     992   BIC:                         1.782e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -1.335e+05   2677.610    -49.842      0.000   -1.39e+05   -1.28e+05
# const                -1.335e+05   2677.610    -49.842      0.000   -1.39e+05   -1.28e+05
# Square_Footage          27.3814      0.044    618.374      0.000      27.295      27.468
# Num_Bedrooms          1403.1488     39.048     35.934      0.000    1326.522    1479.775
# Num_Bathrooms         1128.0964     67.474     16.719      0.000     995.688    1260.505
# Year_Built             138.0598      2.684     51.434      0.000     132.792     143.327
# Lot_Size              2038.5771     42.866     47.557      0.000    1954.459    2122.695
# Garage_Size            682.7054     68.303      9.995      0.000     548.670     816.741
# Neighborhood_Quality    22.6861     19.175      1.183      0.237     -14.942      60.314
# ==============================================================================
# Omnibus:                       12.234   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.512
# Skew:                          -0.274   Prob(JB):                      0.00192
# Kurtosis:                       2.974   Cond. No.                     1.20e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  9e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Report

# %%
results = pd.DataFrame({
    "Sqrt":   getQoF(model_sqrt,   "House_Price", "sqrt"),
    "Log1p":  getQoF(model_log1p,  "House_Price", "log1p"),
    "BoxCox": getQoF(model_boxcox, "House_Price", "boxcox", lam=0.85)
})
print(results)
# Out:
#                Sqrt     Log1p            BoxCox
# rSq           0.986     0.941             0.997
# rSqBar        0.985     0.941             0.997
# sst    29445342.066   241.749 1208110405890.069
# sse      425598.998    14.146    3023790748.106
# sde          20.713     0.119          1745.903
# mse0        429.031     0.014       3048176.157
# rmse         20.713     0.119          1745.903
# mae       24296.468 52989.293         10078.898
# smape         4.858     9.212             2.124
# m          1000.000  1000.000          1000.000
# dfr           7.000     7.000             7.000
# df          992.000   992.000           992.000
# fStat      9662.880  2280.114         56478.111
# aic        8907.375 -1404.442         17775.899
# bic        8946.637 -1365.180         17815.161

# %% [markdown]
# # Medical Cost : Square-Root, Log1p, and Box–Cox Transformations

# %% [markdown]
# ### Data Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import boxcox
from scipy.special import inv_boxcox

insurance = pd.read_csv("insurance_cat2num.csv").dropna()
insurance['charges_sqrt'] = np.sqrt(insurance['charges'])
insurance['charges_log1p'] = np.log1p(insurance['charges'])
insurance['charges_boxcox'] = boxcox(insurance['charges'], 1.31)

insurance.head()
# Out:
#    intercept  age    bmi  children  sex_male  smoker_yes  region_northwest  \
# 0          1   19 27.900         0         0           1                 0
# 1          1   18 33.770         1         1           0                 0
# 2          1   28 33.000         3         1           0                 0
# 3          1   33 22.705         0         1           0                 1
# 4          1   32 28.880         0         1           0                 1
#
#    region_southeast  region_southwest   charges  charges_sqrt  charges_log1p  \
# 0                 0                 1 16884.924       129.942          9.734
# 1                 1                 0  1725.552        41.540          7.454
# 2                 1                 0  4449.462        66.704          8.401
# 3                 0                 0 21984.471       148.272          9.998
# 4                 0                 0  3866.855        62.184          8.260
#
#    charges_boxcox
# 0      263482.200
# 1       13276.377
# 2       45920.257
# 3      372305.790
# 4       38208.403

# %% [markdown]
# ### Medical Cost Regression: Square-Root Transformation

# %%
model_sqrt = smf.ols(formula = 'charges_sqrt ~ intercept + age + bmi + \
                     children + sex_male + smoker_yes + region_northwest +\
                     region_southeast + region_southwest', data=insurance).fit()
print(model_sqrt.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           charges_sqrt   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     587.4
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                -6059.7
# No. Observations:                1338   AIC:                         1.214e+04
# Df Residuals:                    1329   BIC:                         1.218e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.3218      1.833      0.176      0.861      -3.274       3.918
# intercept            0.3218      1.833      0.176      0.861      -3.274       3.918
# age                  1.3983      0.044     31.666      0.000       1.312       1.485
# bmi                  1.0300      0.106      9.704      0.000       0.822       1.238
# children             3.2743      0.511      6.402      0.000       2.271       4.278
# sex_male            -1.9123      1.236     -1.548      0.122      -4.336       0.512
# smoker_yes          90.8717      1.533     59.267      0.000      87.864      93.880
# region_northwest    -2.3767      1.768     -1.345      0.179      -5.844       1.091
# region_southeast    -5.8945      1.776     -3.318      0.001      -9.379      -2.409
# region_southwest    -5.2014      1.774     -2.933      0.003      -8.681      -1.722
# ==============================================================================
# Omnibus:                      480.229   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1605.806
# Skew:                           1.783   Prob(JB):                         0.00
# Kurtosis:                       7.010   Cond. No.                     1.79e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Medical Cost Regression: Log1p Transformation

# %%
model_log1p = smf.ols(formula = 'charges_log1p ~ intercept + age + bmi + \
                     children + sex_male + smoker_yes + region_northwest +\
                     region_southeast + region_southwest', data=insurance).fit()
print(model_log1p.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          charges_log1p   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     549.8
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                -808.27
# No. Observations:                1338   AIC:                             1635.
# Df Residuals:                    1329   BIC:                             1681.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            3.5155      0.036     97.138      0.000       3.445       3.587
# intercept            3.5155      0.036     97.138      0.000       3.445       3.587
# age                  0.0346      0.001     39.655      0.000       0.033       0.036
# bmi                  0.0134      0.002      6.382      0.000       0.009       0.017
# children             0.1018      0.010     10.084      0.000       0.082       0.122
# sex_male            -0.0754      0.024     -3.090      0.002      -0.123      -0.028
# smoker_yes           1.5541      0.030     51.336      0.000       1.495       1.614
# region_northwest    -0.0638      0.035     -1.827      0.068      -0.132       0.005
# region_southeast    -0.1572      0.035     -4.480      0.000      -0.226      -0.088
# region_southwest    -0.1289      0.035     -3.681      0.000      -0.198      -0.060
# ==============================================================================
# Omnibus:                      463.981   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1674.306
# Skew:                           1.679   Prob(JB):                         0.00
# Kurtosis:                       7.331   Cond. No.                     1.79e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Medical Cost Regression: Box-Cox  Transformation

# %%
model_boxcox = smf.ols(formula = 'charges_boxcox ~ intercept + age + bmi + \
                     children + sex_male + smoker_yes + region_northwest +\
                     region_southeast + region_southwest', data=insurance).fit()
print(model_boxcox.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         charges_boxcox   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     430.3
# Date:                Sun, 15 Feb 2026   Prob (F-statistic):               0.00
# Time:                        00:30:30   Log-Likelihood:                -17739.
# No. Observations:                1338   AIC:                         3.550e+04
# Df Residuals:                    1329   BIC:                         3.554e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1.567e+05   1.13e+04    -13.837      0.000   -1.79e+05   -1.34e+05
# intercept        -1.567e+05   1.13e+04    -13.837      0.000   -1.79e+05   -1.34e+05
# age               4554.2817    272.845     16.692      0.000    4019.027    5089.536
# bmi               8219.2708    655.797     12.533      0.000    6932.760    9505.782
# children          7354.6539   3159.903      2.327      0.020    1155.712    1.36e+04
# sex_male           233.4434   7634.573      0.031      0.976   -1.47e+04    1.52e+04
# smoker_yes        5.141e+05   9473.773     54.265      0.000    4.96e+05    5.33e+05
# region_northwest -4812.2150   1.09e+04     -0.441      0.660   -2.62e+04    1.66e+04
# region_southeast -1.792e+04    1.1e+04     -1.633      0.103   -3.95e+04    3612.195
# region_southwest -1.678e+04    1.1e+04     -1.531      0.126   -3.83e+04    4721.313
# ==============================================================================
# Omnibus:                      275.850   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              793.286
# Skew:                           1.047   Prob(JB):                    5.50e-173
# Kurtosis:                       6.137   Cond. No.                     1.79e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.1e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Report

# %%
results = pd.DataFrame({
    "Sqrt":   getQoF(model_sqrt,   "charges", "sqrt"),
    "Log1p":  getQoF(model_log1p,  "charges", "log1p"),
    "BoxCox": getQoF(model_boxcox, "charges", "boxcox", lam=1.31)
})
print(results)
# Out:
#               Sqrt    Log1p             BoxCox
# rSq          0.780    0.768              0.721
# rSqBar       0.778    0.767              0.720
# sst    3051091.513 1130.110 92203700874799.344
# sse     672635.971  262.232 25679991017120.289
# sde         22.497    0.444         139006.447
# mse0       506.122    0.197    19322792337.939
# rmse        22.497    0.444         139006.447
# mae       3613.896 4219.512           4805.541
# smape       27.690   26.289             39.520
# m         1338.000 1338.000           1338.000
# dfr          8.000    8.000              8.000
# df        1329.000 1329.000           1329.000
# fStat      587.422  549.805            430.345
# aic      12137.477 1634.536          35495.979
# bic      12184.268 1681.327          35542.769
